# %%
import os
import sys
import numpy as np
import pandas as pd
import pickle
import random
import time
from joblib import Parallel, delayed
sys.path.append('../')

from packages import actv_analysis, svm
import seaborn as sns
# from packages.svm import SVM_fit
# from packages.load_csv import units_for_svm

# %% [markdown]
# ## Make training and test sets

# %%
nidx=range(1,10)
sidx=range(3,10)
img_inst=500

for i in range(10):
    rep_per_ns_combo=16
    df_idx = svm.gen_SVM_input(nidx=nidx, sidx=sidx, rep_per_ns_combo=rep_per_ns_combo, img_inst=img_inst)
    # save to csv file
    df_idx.to_csv(f'svm_training_set{i}_4to20.csv', index=True)
    
    rep_per_ns_combo=4
    df_idx = svm.gen_SVM_input(nidx=nidx, sidx=sidx, rep_per_ns_combo=rep_per_ns_combo, img_inst=img_inst)
    # save to csv file
    df_idx.to_csv(f'svm_test_set{i}_4to20.csv', index=True)

# %%
import random
import time

# Parameters
#relus = range(2,6)
relus = list(range(4,5))
epochs = np.arange(0, 91, 10)
exps = np.arange(0, 10)
num_units = 100
rate_threshold = 0.05
layer_numunits = {'relu1':290400, 'relu2':186624, 'relu3':64896, 'relu4':64896, 'relu5':43264}

dir_path = os.path.dirname(os.path.realpath('../'))
#path_for_units = f"{dir_path}/dataframes/SVM/units/{num_units} units sampled from distribution higher than {rate_threshold} response rate including PN2 and PN20"
set_folder = f"{dir_path}/dataframes/SVM"  # retrieve training/test sets
save_to_folder = f"{dir_path}/dataframes/SVM_predictions"

for relu in relus:
    for epoch in epochs:
        for net in range(1, 2):
            pkl_filename = f'pkl/network{net}_Relu{relu}_epoch{epoch}.pkl'
            print(f'Loading {pkl_filename}..')
            with open(pkl_filename, 'rb') as f:
                units = pickle.load(f)
            print(f'Loading actv ..')
            actv_net = actv_analysis.get_actv_net(net=net, relu=relu, epoch=epoch)
            actv = actv_net.reshape(list(layer_numunits.values())[relu-1], 10, 10, 500)
            
            # select units whose activities corresponding to images will be used for svm training and testing:
            units_with_someresp = [units[i].id for i in range(len(units)) if units[i].response_rate_subset > rate_threshold]
            
            # Randomly choose "num_units" number of units from units_with_someresp without replacement
            random.seed(exp)
            units = random.sample(units_with_someresp, num_units)
            
            start_time = time.time()
            y_preds = Parallel(n_jobs=-1)(delayed(svm.SVM_fit)(units=units, actv=actv, exp=exp) for exp in exps)
            end_time = time.time()
            print(f"Took {end_time - start_time} seconds to run.")

            [pd.Series(y_preds[exp]).to_csv(f'csv/SVM prediction of He untrained net{net} relu{relu} epoch{epoch} {num_units} units that are randomly drawn from distribution exp{exp} June2023.csv', index=True) for exp in exps]

# %% [markdown]
# ## Run SVM

# %%
relus = list(range(4,5))
epochs = np.arange(0, 91, 10)
exps = np.arange(0, 10)
#num_units = 100
#rate_threshold = 0.05
layer_numunits = {'relu1':290400, 'relu2':186624, 'relu3':64896, 'relu4':64896, 'relu5':43264}

def svm_fit_with_fresh_units(exp, units_nonzero, actv, num_units):
    units_sample = random.sample(units_nonzero, num_units)
    return svm.SVM_fit_with_seed(exp, units_sample, actv)


exps = range(10)
for relu in relus:
    for epoch in epochs:
        for net in range(1, 11):
            pkl_filename = f'pkl/4to20/network{net}_Relu{relu}_epoch{epoch}_4to20.pkl'

            if not os.path.exists(pkl_filename):
                print(f"{pkl_filename} does not exist, skipping.")
                continue

            # Initialize missing_exps_dict as empty dictionary
            missing_exps_dict = {}

            for outer_num_units in np.arange(2000, 2001, 200):
                # Define filenames before processing
                csv_files = {exp: f'csv/svm_results/4to20/SVM prediction of He untrained net{net} relu{relu} epoch{epoch} {outer_num_units} nonzero activity units exp{exp} July2023_4to20.csv' for exp in exps}

                # Filter out the experiments where CSV files already exist
                missing_exps = [exp for exp, filename in csv_files.items() if not os.path.exists(filename)]

                if missing_exps:
                    missing_exps_dict[outer_num_units] = {exp: csv_files[exp] for exp in missing_exps}

            if not missing_exps_dict:
                print(f"All CSV files for net{net} relu{relu} epoch{epoch} already exist, skipping.")
                continue

            print(f'Loading {pkl_filename} and actv file..')
            with open(pkl_filename, 'rb') as f:
                units = pickle.load(f)

            actv_net = actv_analysis.get_actv_net(net=net, relu=relu, epoch=epoch)
            actv = actv_net.reshape(list(layer_numunits.values())[relu-1], 10, 10, 500)

            # select units whose activities corresponding to images will be used for svm training and testing:
            units_nonzero = [units[i].id for i in range(len(units)) if units[i].no_response_subset is not True]

            for outer_num_units in np.arange(2000, 2001, 200):
                if outer_num_units not in missing_exps_dict:
                    print(f"All CSV files for net{net} relu{relu} epoch{epoch} num_units {outer_num_units} already exist, skipping.")
                    continue

                units_sample = random.sample(units_nonzero, outer_num_units)

                start_time = time.time()

                # Parallelize only the missing experiments
                #y_preds = Parallel(n_jobs=-1)(delayed(svm.SVM_fit_shuffled_with_seed)(exp, units_sample, actv) for exp in missing_exps_dict[outer_num_units].keys())
                # Parallelize only the missing experiments
                y_preds = Parallel(n_jobs=-1)(delayed(svm_fit_with_fresh_units)(exp, units_nonzero, actv, outer_num_units) for exp in missing_exps_dict[outer_num_units].keys())


                # Save results to CSV
                for exp, y_pred in zip(missing_exps_dict[outer_num_units].keys(), y_preds):
                    pd.Series(y_pred).to_csv(missing_exps_dict[outer_num_units][exp], index=True)

                end_time = time.time()
                print(f"Took {end_time - start_time} seconds to run for num_units {outer_num_units}.")
# Out:
# Loading pkl/4to20/network1_Relu4_epoch0_4to20.pkl and actv file..
# --- 109.15813183784485 seconds ---
# Took 173.38850498199463 seconds to run for num_units 2000.
# Loading pkl/4to20/network2_Relu4_epoch0_4to20.pkl and actv file..
# --- 113.90224409103394 seconds ---
# Took 158.31243705749512 seconds to run for num_units 2000.
# Loading pkl/4to20/network3_Relu4_epoch0_4to20.pkl and actv file..
# --- 113.8326690196991 seconds ---
# Took 165.8712718486786 seconds to run for num_units 2000.
# Loading pkl/4to20/network4_Relu4_epoch0_4to20.pkl and actv file..
# --- 110.76162481307983 seconds ---
# Took 155.06944727897644 seconds to run for num_units 2000.
# Loading pkl/4to20/network5_Relu4_epoch0_4to20.pkl and actv file..
# --- 113.12110710144043 seconds ---
# Took 144.1522970199585 seconds to run for num_units 2000.
# Loading pkl/4to20/network6_Relu4_epoch0_4to20.pkl and actv file..
# --- 117.75188612937927 seconds ---
# Took 201.19531083106995 seconds to run for num_units 2000.
# Loading pkl/4to20/network7_Relu4_epoch0_4to20.pkl and actv file..
# --- 109.992027759552 seconds ---
# Took 156.4604799747467 seconds to run for num_units 2000.
# Loading pkl/4to20/network8_Relu4_epoch0_4to20.pkl and actv file..
# --- 110.97530198097229 seconds ---
# Took 145.68425512313843 seconds to run for num_units 2000.
# Loading pkl/4to20/network9_Relu4_epoch0_4to20.pkl and actv file..
# --- 110.41466903686523 seconds ---
# Took 152.69436073303223 seconds to run for num_units 2000.
# Loading pkl/4to20/network10_Relu4_epoch0_4to20.pkl and actv file..
# --- 114.2492778301239 seconds ---
# Took 161.10406589508057 seconds to run for num_units 2000.
# Loading pkl/4to20/network1_Relu4_epoch10_4to20.pkl and actv file..
# --- 80.71355962753296 seconds ---
# Took 60.32758402824402 seconds to run for num_units 2000.
# Loading pkl/4to20/network2_Relu4_epoch10_4to20.pkl and actv file..
# --- 80.07188391685486 seconds ---
# Took 62.54720997810364 seconds to run for num_units 2000.
# Loading pkl/4to20/network3_Relu4_epoch10_4to20.pkl and actv file..
# --- 82.01126909255981 seconds ---
# Took 62.7734272480011 seconds to run for num_units 2000.
# Loading pkl/4to20/network4_Relu4_epoch10_4to20.pkl and actv file..
# --- 80.10420799255371 seconds ---
# Took 61.09207582473755 seconds to run for num_units 2000.
# Loading pkl/4to20/network5_Relu4_epoch10_4to20.pkl and actv file..
# --- 79.7897219657898 seconds ---
# Took 62.41371393203735 seconds to run for num_units 2000.
# Loading pkl/4to20/network6_Relu4_epoch10_4to20.pkl and actv file..
# --- 79.04255318641663 seconds ---
# Took 59.48755097389221 seconds to run for num_units 2000.
# Loading pkl/4to20/network7_Relu4_epoch10_4to20.pkl and actv file..
# --- 76.52343583106995 seconds ---
# Took 58.93053698539734 seconds to run for num_units 2000.
# Loading pkl/4to20/network8_Relu4_epoch10_4to20.pkl and actv file..
# --- 76.45589590072632 seconds ---
# Took 60.01043391227722 seconds to run for num_units 2000.
# Loading pkl/4to20/network9_Relu4_epoch10_4to20.pkl and actv file..
# --- 80.18323493003845 seconds ---
# Took 63.37867999076843 seconds to run for num_units 2000.
# Loading pkl/4to20/network10_Relu4_epoch10_4to20.pkl and actv file..
# --- 76.85566282272339 seconds ---
# Took 60.49935603141785 seconds to run for num_units 2000.
# Loading pkl/4to20/network1_Relu4_epoch20_4to20.pkl and actv file..
# --- 75.23554611206055 seconds ---
# Took 60.61327624320984 seconds to run for num_units 2000.
# Loading pkl/4to20/network2_Relu4_epoch20_4to20.pkl and actv file..
# --- 79.84919333457947 seconds ---
# Took 60.8455970287323 seconds to run for num_units 2000.
# Loading pkl/4to20/network3_Relu4_epoch20_4to20.pkl and actv file..
# --- 76.23144602775574 seconds ---
# Took 60.043471336364746 seconds to run for num_units 2000.
# Loading pkl/4to20/network4_Relu4_epoch20_4to20.pkl and actv file..
# --- 75.09891104698181 seconds ---
# Took 59.21133995056152 seconds to run for num_units 2000.
# Loading pkl/4to20/network5_Relu4_epoch20_4to20.pkl and actv file..
# --- 74.91279697418213 seconds ---
# Took 59.370185136795044 seconds to run for num_units 2000.
# Loading pkl/4to20/network6_Relu4_epoch20_4to20.pkl and actv file..
# --- 76.58701586723328 seconds ---
# Took 60.54520297050476 seconds to run for num_units 2000.
# Loading pkl/4to20/network7_Relu4_epoch20_4to20.pkl and actv file..
# --- 81.88629007339478 seconds ---
# Took 61.141618967056274 seconds to run for num_units 2000.
# Loading pkl/4to20/network8_Relu4_epoch20_4to20.pkl and actv file..
# --- 76.86574387550354 seconds ---
# Took 60.53678011894226 seconds to run for num_units 2000.
# Loading pkl/4to20/network9_Relu4_epoch20_4to20.pkl and actv file..
# --- 74.42413592338562 seconds ---
# Took 59.43905687332153 seconds to run for num_units 2000.
# Loading pkl/4to20/network10_Relu4_epoch20_4to20.pkl and actv file..
# --- 75.33397006988525 seconds ---
# Took 60.52241802215576 seconds to run for num_units 2000.
# Loading pkl/4to20/network1_Relu4_epoch30_4to20.pkl and actv file..
# --- 76.8895800113678 seconds ---
# Took 60.99458718299866 seconds to run for num_units 2000.
# Loading pkl/4to20/network2_Relu4_epoch30_4to20.pkl and actv file..
# --- 75.2123589515686 seconds ---
# Took 61.0567102432251 seconds to run for num_units 2000.
# Loading pkl/4to20/network3_Relu4_epoch30_4to20.pkl and actv file..
# --- 77.33885598182678 seconds ---
# Took 60.83455491065979 seconds to run for num_units 2000.
# Loading pkl/4to20/network4_Relu4_epoch30_4to20.pkl and actv file..
# --- 77.52762794494629 seconds ---
# Took 59.524040937423706 seconds to run for num_units 2000.
# Loading pkl/4to20/network5_Relu4_epoch30_4to20.pkl and actv file..
# --- 75.53889584541321 seconds ---
# Took 60.51990604400635 seconds to run for num_units 2000.
# Loading pkl/4to20/network6_Relu4_epoch30_4to20.pkl and actv file..
# --- 75.93666815757751 seconds ---
# Took 60.223498821258545 seconds to run for num_units 2000.
# Loading pkl/4to20/network7_Relu4_epoch30_4to20.pkl and actv file..
# --- 74.30699014663696 seconds ---
# Took 58.567716121673584 seconds to run for num_units 2000.
# Loading pkl/4to20/network8_Relu4_epoch30_4to20.pkl and actv file..
# --- 74.82106399536133 seconds ---
# Took 60.99622821807861 seconds to run for num_units 2000.
# Loading pkl/4to20/network9_Relu4_epoch30_4to20.pkl and actv file..
# --- 77.7280011177063 seconds ---
# Took 62.077555894851685 seconds to run for num_units 2000.
# Loading pkl/4to20/network10_Relu4_epoch30_4to20.pkl and actv file..
# --- 75.37259602546692 seconds ---
# Took 60.59619688987732 seconds to run for num_units 2000.
# Loading pkl/4to20/network1_Relu4_epoch40_4to20.pkl and actv file..
# --- 83.68033289909363 seconds ---
# Took 60.994811058044434 seconds to run for num_units 2000.
# Loading pkl/4to20/network2_Relu4_epoch40_4to20.pkl and actv file..
# --- 84.38482093811035 seconds ---
# Took 63.34097385406494 seconds to run for num_units 2000.
# Loading pkl/4to20/network3_Relu4_epoch40_4to20.pkl and actv file..
# --- 84.84962105751038 seconds ---
# Took 65.96580195426941 seconds to run for num_units 2000.
# Loading pkl/4to20/network4_Relu4_epoch40_4to20.pkl and actv file..
# --- 88.59540390968323 seconds ---
# Took 65.91888785362244 seconds to run for num_units 2000.
# Loading pkl/4to20/network5_Relu4_epoch40_4to20.pkl and actv file..
# --- 88.61654019355774 seconds ---
# Took 69.70789575576782 seconds to run for num_units 2000.
# Loading pkl/4to20/network6_Relu4_epoch40_4to20.pkl and actv file..
# --- 88.08791494369507 seconds ---
# Took 69.27231216430664 seconds to run for num_units 2000.
# Loading pkl/4to20/network7_Relu4_epoch40_4to20.pkl and actv file..
# --- 87.36875700950623 seconds ---
# Took 66.35179328918457 seconds to run for num_units 2000.
# Loading pkl/4to20/network8_Relu4_epoch40_4to20.pkl and actv file..
# --- 89.315593957901 seconds ---
# Took 67.26424407958984 seconds to run for num_units 2000.
# Loading pkl/4to20/network9_Relu4_epoch40_4to20.pkl and actv file..
# --- 88.24938201904297 seconds ---
# Took 65.471510887146 seconds to run for num_units 2000.
# Loading pkl/4to20/network10_Relu4_epoch40_4to20.pkl and actv file..
# --- 88.57659196853638 seconds ---
# Took 66.5876317024231 seconds to run for num_units 2000.
# Loading pkl/4to20/network1_Relu4_epoch50_4to20.pkl and actv file..
# --- 93.38901090621948 seconds ---
# Took 66.70907068252563 seconds to run for num_units 2000.
# Loading pkl/4to20/network2_Relu4_epoch50_4to20.pkl and actv file..
# --- 93.61693906784058 seconds ---
# Took 68.72727394104004 seconds to run for num_units 2000.
# Loading pkl/4to20/network3_Relu4_epoch50_4to20.pkl and actv file..
# --- 93.03547286987305 seconds ---
# Took 67.2339608669281 seconds to run for num_units 2000.
# Loading pkl/4to20/network4_Relu4_epoch50_4to20.pkl and actv file..
# --- 93.27412986755371 seconds ---
# Took 68.14253783226013 seconds to run for num_units 2000.
# Loading pkl/4to20/network5_Relu4_epoch50_4to20.pkl and actv file..
# --- 93.12480783462524 seconds ---
# Took 66.61797714233398 seconds to run for num_units 2000.
# Loading pkl/4to20/network6_Relu4_epoch50_4to20.pkl and actv file..
# --- 94.5887382030487 seconds ---
# Took 69.26476407051086 seconds to run for num_units 2000.
# Loading pkl/4to20/network7_Relu4_epoch50_4to20.pkl and actv file..
# --- 92.20622897148132 seconds ---
# Took 67.6924500465393 seconds to run for num_units 2000.
# Loading pkl/4to20/network8_Relu4_epoch50_4to20.pkl and actv file..
# --- 89.1810097694397 seconds ---
# Took 66.60681200027466 seconds to run for num_units 2000.
# Loading pkl/4to20/network9_Relu4_epoch50_4to20.pkl and actv file..
# --- 87.53217697143555 seconds ---
# Took 65.20839500427246 seconds to run for num_units 2000.
# Loading pkl/4to20/network10_Relu4_epoch50_4to20.pkl and actv file..
# --- 89.35014128684998 seconds ---
# Took 67.6921911239624 seconds to run for num_units 2000.
# Loading pkl/4to20/network1_Relu4_epoch60_4to20.pkl and actv file..
# --- 89.61513805389404 seconds ---
# Took 65.68145298957825 seconds to run for num_units 2000.
# Loading pkl/4to20/network2_Relu4_epoch60_4to20.pkl and actv file..
# --- 89.27357125282288 seconds ---
# Took 67.08197498321533 seconds to run for num_units 2000.
# Loading pkl/4to20/network3_Relu4_epoch60_4to20.pkl and actv file..
# --- 90.1342601776123 seconds ---
# Took 69.3365330696106 seconds to run for num_units 2000.
# Loading pkl/4to20/network4_Relu4_epoch60_4to20.pkl and actv file..
# --- 90.83909225463867 seconds ---
# Took 67.25841188430786 seconds to run for num_units 2000.
# Loading pkl/4to20/network5_Relu4_epoch60_4to20.pkl and actv file..
# --- 91.92727088928223 seconds ---
# Took 66.67161679267883 seconds to run for num_units 2000.
# Loading pkl/4to20/network6_Relu4_epoch60_4to20.pkl and actv file..
# --- 91.34761881828308 seconds ---
# Took 68.20664501190186 seconds to run for num_units 2000.
# Loading pkl/4to20/network7_Relu4_epoch60_4to20.pkl and actv file..
# --- 89.5226240158081 seconds ---
# Took 64.8370532989502 seconds to run for num_units 2000.
# Loading pkl/4to20/network8_Relu4_epoch60_4to20.pkl and actv file..
# --- 92.49702286720276 seconds ---
# Took 68.04823279380798 seconds to run for num_units 2000.
# Loading pkl/4to20/network9_Relu4_epoch60_4to20.pkl and actv file..
# --- 88.17153000831604 seconds ---
# Took 65.19903302192688 seconds to run for num_units 2000.
# Loading pkl/4to20/network10_Relu4_epoch60_4to20.pkl and actv file..
# --- 89.55596899986267 seconds ---
# Took 64.65951323509216 seconds to run for num_units 2000.
# Loading pkl/4to20/network1_Relu4_epoch70_4to20.pkl and actv file..
# --- 95.06701612472534 seconds ---
# Took 68.72966194152832 seconds to run for num_units 2000.
# Loading pkl/4to20/network2_Relu4_epoch70_4to20.pkl and actv file..
# --- 96.90091514587402 seconds ---
# Took 69.18976378440857 seconds to run for num_units 2000.
# Loading pkl/4to20/network3_Relu4_epoch70_4to20.pkl and actv file..
# --- 98.16472506523132 seconds ---
# Took 70.51899099349976 seconds to run for num_units 2000.
# Loading pkl/4to20/network4_Relu4_epoch70_4to20.pkl and actv file..
# --- 97.30207324028015 seconds ---
# Took 69.15704202651978 seconds to run for num_units 2000.
# Loading pkl/4to20/network5_Relu4_epoch70_4to20.pkl and actv file..
# --- 92.975830078125 seconds ---
# Took 69.47854804992676 seconds to run for num_units 2000.
# Loading pkl/4to20/network6_Relu4_epoch70_4to20.pkl and actv file..
# --- 97.18881487846375 seconds ---
# Took 70.91584181785583 seconds to run for num_units 2000.
# Loading pkl/4to20/network7_Relu4_epoch70_4to20.pkl and actv file..
# --- 93.44105291366577 seconds ---
# Took 66.78460884094238 seconds to run for num_units 2000.
# Loading pkl/4to20/network8_Relu4_epoch70_4to20.pkl and actv file..
# --- 98.24385690689087 seconds ---
# Took 70.84903883934021 seconds to run for num_units 2000.
# Loading pkl/4to20/network9_Relu4_epoch70_4to20.pkl and actv file..
# --- 95.47689604759216 seconds ---
# Took 70.93370318412781 seconds to run for num_units 2000.
# Loading pkl/4to20/network10_Relu4_epoch70_4to20.pkl and actv file..
# --- 93.93570899963379 seconds ---
# Took 68.8359739780426 seconds to run for num_units 2000.
# Loading pkl/4to20/network1_Relu4_epoch80_4to20.pkl and actv file..
# --- 96.49425482749939 seconds ---
# Took 68.85049700737 seconds to run for num_units 2000.
# Loading pkl/4to20/network2_Relu4_epoch80_4to20.pkl and actv file..
# --- 95.47014212608337 seconds ---
# Took 69.6827039718628 seconds to run for num_units 2000.
# Loading pkl/4to20/network3_Relu4_epoch80_4to20.pkl and actv file..
# --- 95.04446005821228 seconds ---
# Took 68.6660258769989 seconds to run for num_units 2000.
# Loading pkl/4to20/network4_Relu4_epoch80_4to20.pkl and actv file..
# --- 96.73849391937256 seconds ---
# Took 72.38428592681885 seconds to run for num_units 2000.
# Loading pkl/4to20/network5_Relu4_epoch80_4to20.pkl and actv file..
# --- 95.59353995323181 seconds ---
# Took 70.1995677947998 seconds to run for num_units 2000.
# Loading pkl/4to20/network6_Relu4_epoch80_4to20.pkl and actv file..
# --- 97.05029487609863 seconds ---
# Took 69.98722100257874 seconds to run for num_units 2000.
# Loading pkl/4to20/network7_Relu4_epoch80_4to20.pkl and actv file..
# --- 96.03773331642151 seconds ---
# Took 70.22909188270569 seconds to run for num_units 2000.
# Loading pkl/4to20/network8_Relu4_epoch80_4to20.pkl and actv file..
# --- 97.67109513282776 seconds ---
# Took 70.57082891464233 seconds to run for num_units 2000.
# Loading pkl/4to20/network9_Relu4_epoch80_4to20.pkl and actv file..
# --- 97.9168450832367 seconds ---
# Took 71.02550101280212 seconds to run for num_units 2000.
# Loading pkl/4to20/network10_Relu4_epoch80_4to20.pkl and actv file..
# --- 97.20514631271362 seconds ---
# Took 74.5947117805481 seconds to run for num_units 2000.
# Loading pkl/4to20/network1_Relu4_epoch90_4to20.pkl and actv file..
# --- 100.42155075073242 seconds ---
# Took 72.81004691123962 seconds to run for num_units 2000.
# Loading pkl/4to20/network2_Relu4_epoch90_4to20.pkl and actv file..
# --- 97.77477717399597 seconds ---
# Took 71.6427812576294 seconds to run for num_units 2000.
# Loading pkl/4to20/network3_Relu4_epoch90_4to20.pkl and actv file..
# --- 97.4247989654541 seconds ---
# Took 72.59267807006836 seconds to run for num_units 2000.
# Loading pkl/4to20/network4_Relu4_epoch90_4to20.pkl and actv file..
# --- 100.10539484024048 seconds ---
# Took 73.94600796699524 seconds to run for num_units 2000.
# Loading pkl/4to20/network5_Relu4_epoch90_4to20.pkl and actv file..
# --- 98.2782199382782 seconds ---
# Took 72.22097992897034 seconds to run for num_units 2000.
# Loading pkl/4to20/network6_Relu4_epoch90_4to20.pkl and actv file..
# --- 98.17714715003967 seconds ---
# Took 72.65482902526855 seconds to run for num_units 2000.
# Loading pkl/4to20/network7_Relu4_epoch90_4to20.pkl and actv file..
# --- 96.96438026428223 seconds ---
# Took 70.0698938369751 seconds to run for num_units 2000.
# Loading pkl/4to20/network8_Relu4_epoch90_4to20.pkl and actv file..
# --- 99.36345481872559 seconds ---
# Took 74.55022406578064 seconds to run for num_units 2000.
# Loading pkl/4to20/network9_Relu4_epoch90_4to20.pkl and actv file..
# --- 100.27221131324768 seconds ---
# Took 72.35323810577393 seconds to run for num_units 2000.
# Loading pkl/4to20/network10_Relu4_epoch90_4to20.pkl and actv file..
# --- 100.2480411529541 seconds ---
# Took 76.64705801010132 seconds to run for num_units 2000.

# %% [markdown]
# ## Run SVM with specific types of units

# %%
relus = np.arange(4,5)
epochs = np.arange(90, 91, 10)
exps = np.arange(0, 10)
#num_units = 100
#rate_threshold = 0.05
layer_numunits = {'relu1':290400, 'relu2':186624, 'relu3':64896, 'relu4':64896, 'relu5':43264}
outer_num_units = 200

exps = range(10)
for relu in relus:
    for epoch in epochs:
        for net in range(1, 3):
            pkl_filename = f'pkl/network{net}_Relu{relu}_epoch{epoch}.pkl'

            if not os.path.exists(pkl_filename):
                print(f"{pkl_filename} does not exist, skipping.")
                continue

            # Initialize missing_exps_dict as empty dictionary
            missing_exps_dict = {}

            print(f'Loading {pkl_filename} and actv file..')
            with open(pkl_filename, 'rb') as f:
                units = pickle.load(f)

            actv_net = actv_analysis.get_actv_net(net=net, relu=relu, epoch=epoch)
            actv = actv_net.reshape(list(layer_numunits.values())[relu-1], 10, 10, 500)

            # select units whose activities corresponding to images will be used for svm training and testing:
            #units_nonzero = [units[i].id for i in range(len(units)) if units[i].no_response_subset is not True]
            sn = [units[i].spearmanr_number for i in range(len(units))]
            ss = [units[i].spearmanr_size for i in range(len(units))]
            df_spearmanr = pd.DataFrame({'sn':sn, 'ss':ss})
            # LNSS = df_spearmanr[(df_spearmanr['sn']>0.9) &( df_spearmanr['ss']<-0.9)].index
            # LNLS = df_spearmanr[(df_spearmanr['sn']>0.9) &( df_spearmanr['ss']>0.9)].index
            SNLS = df_spearmanr[(df_spearmanr['sn']<-0.9) &( df_spearmanr['ss']>0.9)].index
            SNSS = df_spearmanr[(df_spearmanr['sn']<-0.9) &( df_spearmanr['ss']<-0.9)].index
            type1 = SNLS; type2 = SNSS

            for type1_prop in np.arange(0, 1.1, 0.1):
                type2_prop = round(1-type1_prop, 1)

                type1_sample = random.sample(list(type1), int(outer_num_units*type1_prop))
                type2_sample = random.sample(list(type2), int(outer_num_units*type2_prop))
                units_sample = np.union1d(type1_sample, type2_sample).astype(int)

                start_time = time.time()

                y_preds = Parallel(n_jobs=-1)(delayed(svm.SVM_fit_with_seed)(exp, units_sample, actv) for exp in exps)

                # Save results to CSV
                for exp, y_pred in zip(exps, y_preds):
                    csv_file = f'csv/svm_results/SVM_prediction_of_He_untrained_net{net}_relu{relu}_epoch{epoch}_{int(100*type1_prop)}_percent_SNLS_and_{int(100*type2_prop)}_percent_SNSS_units_exp{exp}_July2023.csv'
                    df = pd.DataFrame({'y_pred': y_pred})
                    df.to_csv(csv_file, index=False)

                end_time = time.time()
                print(f"It took {end_time - start_time} seconds to run for num_units {outer_num_units}.")

# %%
net=1; relu=4; epoch=90
pkl_filename = f'pkl/network{net}_Relu{relu}_epoch{epoch}.pkl'
with open(pkl_filename, 'rb') as f:
    units = pickle.load(f)

# %%
sn = [units[i].spearmanr_number for i in range(len(units))]
ss = [units[i].spearmanr_size for i in range(len(units))]

# %%
np.union1d(np.arange(0,1.1,0.1), np.arange(0,2.1,0.2))

# %%
df_spearmanr = pd.DataFrame(spearmanr = {'sn':sn, 'ss':ss})

# %%
LNSS = df_spearmanr[(df_spearmanr['sn']>0.9) &( df_spearmanr['ss']<-0.9)].index

# %%
net=1; relu=5; epoch=90

pkl_filename = f'pkl/network{net}_Relu{relu}_epoch{epoch}_4to20.pkl'

with open(pkl_filename, 'rb') as f:
    units = pickle.load(f)

# %%
np.sum([units[i].PN == 4 for i in range(len(units))])
